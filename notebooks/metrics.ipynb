# %%
# !wget https://github.com/irsafilo/KION_DATASET/raw/f69775be31fa5779907cf0a92ddedb70037fb5ae/data_original.zip
# !unzip data_original.zip

# %%
# !pip install rectools

# %%
import pandas as pd
import numpy as np

from time import time
from tqdm import tqdm

from rectools import Columns
from rectools.dataset import Interactions, Dataset
from rectools.metrics import (
    Precision,
    Recall,
    MAP,
    MRR,
    MeanInvUserFreq,
    Serendipity,
    calc_metrics,
)
from rectools.models import RandomModel, PopularModel
from rectools.model_selection import TimeRangeSplitter

# %%
interactions = pd.read_csv("data_original/interactions.csv")
interactions.head()
# Out:
#    user_id  item_id last_watch_dt  total_dur  watched_pct
# 0   176549     9506    2021-05-11       4250         72.0
# 1   699317     1659    2021-05-29       8317        100.0
# 2   656683     7107    2021-05-09         10          0.0
# 3   864613     7638    2021-07-05      14483        100.0
# 4   964868     9506    2021-04-30       6725        100.0

# %%
interactions["weight"] = interactions["watched_pct"] / 100
interactions["datetime"] = pd.to_datetime(interactions["last_watch_dt"])
interactions.drop(
    labels=["last_watch_dt", "watched_pct", "total_dur"], axis=1, inplace=True
)

# %%
interactions = Interactions(interactions)

# %%
n_splits = 3

# %%
def eval(models: dict, metrics: dict, splitter, k_recos: int) -> None:
    results = []

    fold_iterator = splitter.split(interactions, collect_fold_stats=True)

    for train_ids, test_ids, fold_info in tqdm((fold_iterator), total=n_splits):
        print(f"\n==================== Fold {fold_info['i_split']}")

        df_train = interactions.df.iloc[train_ids]
        dataset = Dataset.construct(df_train)

        df_test = interactions.df.iloc[test_ids][Columns.UserItem]
        test_users = np.unique(df_test[Columns.User])

        catalog = df_train[Columns.Item].unique()

        for model_name, model in models.items():
            time_start = time()
            model.fit(dataset)
            time_end = time()
            print(f"{model_name} model train time: {time_end - time_start:.6f}s")
            recos = model.recommend(
                users=test_users,
                dataset=dataset,
                k=k_recos,
                filter_viewed=True,
            )
            metric_values = calc_metrics(
                metrics,
                reco=recos,
                interactions=df_test,
                prev_interactions=df_train,
                catalog=catalog,
            )
            res = {"fold": fold_info["i_split"], "model": model_name}
            res.update(metric_values)
            results.append(res)

    results = pd.DataFrame(results).drop(columns="fold").groupby("model").mean()

    return results

# %%
def visualize(model, dataset, user_ids: list, item_data: list):
    recos = model.recommend(users=user_ids, dataset=dataset, filter_viewed=True, k=10)
    recos = recos.drop(columns=["score", "rank"])
    recos["watched"] = 0
    interactions = dataset.interactions.df.drop(columns=["weight", "datetime"])
    interactions = interactions.loc[interactions["user_id"].isin(user_ids)]
    interactions["watched"] = 1
    interactions = pd.concat((interactions, recos), axis=0, ignore_index=True)
    history = pd.merge(interactions, items[["item_id"] + item_data], on="item_id")
    return history

# %%
models = {"random": RandomModel(random_state=32), "popular": PopularModel()}

metrics = {
    "prec@1": Precision(k=1),
    "prec@5": Precision(k=5),
    "prec@10": Precision(k=10),
    "recall@1": Recall(k=1),
    "recall@5": Recall(k=5),
    "recall@10": Recall(k=10),
    "map@1": MAP(k=1),
    "map@5": MAP(k=5),
    "map@10": MAP(k=10),
    "mrr@1": MRR(k=1),
    "mrr@5": MRR(k=5),
    "mrr@10": MRR(k=10),
    "novelty@1": MeanInvUserFreq(k=1),
    "novelty@5": MeanInvUserFreq(k=5),
    "novelty@10": MeanInvUserFreq(k=10),
    "serendipity@1": Serendipity(k=1),
    "serendipity@5": Serendipity(k=5),
    "serendipity@10": Serendipity(k=10),
}

splitter = TimeRangeSplitter(
    test_size="14D",
    n_splits=n_splits,
    filter_already_seen=True,
    filter_cold_items=True,
    filter_cold_users=True,
)

# %%
res = eval(models, metrics, splitter, k_recos=10)
res
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# ==================== Fold 0
# random model train time: 0.000070s
# popular model train time: 2.242789s
#  33%|███▎      | 1/3 [00:41<01:23, 41.68s/it]
# ==================== Fold 1
# random model train time: 0.000075s
# popular model train time: 2.079313s
#  67%|██████▋   | 2/3 [01:29<00:45, 45.10s/it]
# ==================== Fold 2
# random model train time: 0.000082s
# popular model train time: 2.841973s
# 100%|██████████| 3/3 [02:20<00:00, 46.88s/it]
#            prec@1  recall@1    prec@5  recall@5   prec@10  recall@10  \
# model
# popular  0.097211  0.047186  0.070339  0.160496  0.045964   0.203517
# random   0.000203  0.000055  0.000225  0.000293  0.000229   0.000634
#
#             mrr@1     mrr@5    mrr@10     map@1     map@5    map@10  \
# model
# popular  0.097211  0.168272  0.176720  0.047186  0.091013  0.098549
# random   0.000203  0.000499  0.000647  0.000055  0.000135  0.000179
#
#          novelty@1  novelty@5  novelty@10  serendipity@1  serendipity@5  \
# model
# popular   2.422735   3.109863    3.722852       0.000003       0.000004
# random   15.567096  15.555586   15.557718       0.000008       0.000008
#
#          serendipity@10
# model
# popular        0.000003
# random         0.000008

# %%
dataset = Dataset.construct(interactions.df)
# model = RandomModel(random_state=32)
user_ids = [666262, 672861, 955527]
item_data = ["title", "genres", "views"]

# %%
items = pd.read_csv("data_original/items.csv")
items = pd.merge(
    items,
    interactions.df.groupby("item_id").count()["user_id"].rename("views"),
    on="item_id",
    how="left",
)
items.head()
# Out:
#    item_id content_type                 title      title_orig  release_year  \
# 0    10711         film        Поговори с ней  Hable con ella        2002.0
# 1     2508         film           Голые перцы    Search Party        2014.0
# 2    10716         film      Тактическая сила  Tactical Force        2011.0
# 3     7868         film                45 лет        45 Years        2015.0
# 4    16268         film  Все решает мгновение             NaN        1978.0
#
#                                              genres       countries  for_kids  \
# 0           драмы, зарубежные, детективы, мелодрамы         Испания       NaN
# 1                  зарубежные, приключения, комедии             США       NaN
# 2  криминал, зарубежные, триллеры, боевики, комедии          Канада       NaN
# 3                      драмы, зарубежные, мелодрамы  Великобритания       NaN
# 4                драмы, спорт, советские, мелодрамы            СССР       NaN
#
#    age_rating   studios         directors  \
# 0        16.0       NaN  Педро Альмодовар
# 1        16.0       NaN    Скот Армстронг
# 2        16.0       NaN  Адам П. Калтраро
# 3        16.0       NaN         Эндрю Хэй
# 4        12.0  Ленфильм  Виктор Садовский
#
#                                               actors  \
# 0  Адольфо Фернандес, Ана Фернандес, Дарио Гранди...
# 1  Адам Палли, Брайан Хаски, Дж.Б. Смув, Джейсон ...
# 2  Адриан Холмс, Даррен Шалави, Джерри Вассерман,...
# 3  Александра Риддлстон-Барретт, Джеральдин Джейм...
# 4  Александр Абдулов, Александр Демьяненко, Алекс...
#
#                                          description  \
# 0  Мелодрама легендарного Педро Альмодовара «Пого...
# 1  Уморительная современная комедия на популярную...
# 2  Профессиональный рестлер Стив Остин («Все или ...
# 3  Шарлотта Рэмплинг, Том Кортни, Джеральдин Джей...
# 4  Расчетливая чаровница из советского кинохита «...
#
#                                             keywords  views
# 0  Поговори, ней, 2002, Испания, друзья, любовь, ...    5.0
# 1  Голые, перцы, 2014, США, друзья, свадьбы, прео...    9.0
# 2  Тактическая, сила, 2011, Канада, бандиты, ганг...    6.0
# 3  45, лет, 2015, Великобритания, брак, жизнь, лю...    2.0
# 4  Все, решает, мгновение, 1978, СССР, сильные, ж...    1.0

# %%
res = visualize(models["random"], dataset, user_ids, item_data)
res
# Out:
#     user_id  item_id  watched                                         title  \
# 0    666262       93        1                          Дом ночных призраков
# 1    672861       25        1                 Медвежонок Винни и его друзья
# 2    672861       32        1                                В ритме сердца
# 3    955527       21        1                                   Признание 5
# 4    666262    10101        0                           Возвращение Будулая
# 5    666262      619        0  Новые приключения Аладдина (жестовым языком)
# 6    666262    12618        0                             Пропавшая грамота
# 7    666262     5967        0                               Братья вне игры
# 8    666262     4041        0                                    Фрилансеры
# 9    666262     5701        0                    Алые паруса: Новая история
# 10   666262     9738        0                              Женщина в беде 3
# 11   666262    15247        0                      Гордость и предубеждение
# 12   666262    10004        0                                    Болванчики
# 13   666262     2816        0                        Избави нас от лукавого
# 14   672861     9457        0                     Комната (жестовым языком)
# 15   672861    15730        0                          Твое подтянутое тело
# 16   672861      473        0                             Кто такой Букабу?
# 17   672861    12736        0                                         Палач
# 18   672861     3927        0                                    Помни меня
# 19   672861     3300        0                    Антилопа Гну. Южная Африка
# 20   672861     5334        0                                 Boys and Toys
# 21   672861     3087        0                                Жуки - караоке
# 22   672861     4416        0                                         Питер
# 23   672861     5928        0                                Кровавый стрим
# 24   955527     4205        0          Дело гастронома №1 (Операция Беркут)
# 25   955527    10822        0                           Она защищает Родину
# 26   955527    10914        0                                  Великолепная
# 27   955527     3999        0                               Джиперс криперс
# 28   955527    15756        0  Ремнант: Всё ещё вижу тебя (жестовым языком)
# 29   955527    14961        0                                Битва за Землю
# 30   955527    13734        0                 Сексуальный массаж и Фантазии
# 31   955527     3407        0                                Черный капитан
# 32   955527    14614        0                                         Настя
# 33   955527     8300        0                             Поцелуйте невесту
#
#                                              genres   views
# 0            зарубежные, криминал, детективы, ужасы     1.0
# 1         мюзиклы, мультфильм, приключения, комедии    47.0
# 2                         драмы, мюзиклы, мелодрамы   181.0
# 3                                      для взрослых    12.0
# 4                                         мелодрамы    99.0
# 5                               зарубежные, комедии     1.0
# 6                                  фэнтези, комедии    51.0
# 7                                      драмы, спорт   262.0
# 8   криминал, детективы, драмы, зарубежные, боевики    19.0
# 9                                комедии, мелодрамы     4.0
# 10                             детективы, мелодрамы     2.0
# 11                                 драмы, мелодрамы   150.0
# 12                 мультфильм, приключения, комедии    51.0
# 13                       ужасы, триллеры, детективы  1370.0
# 14                      драмы, зарубежные, триллеры     5.0
# 15                                           фитнес     2.0
# 16       развлекательные, для детей, документальное    15.0
# 17                       драмы, зарубежные, комедии     3.0
# 18                                 драмы, мелодрамы  2982.0
# 19                                   документальное     8.0
# 20                                         no_genre     3.0
# 21                                         no_genre     1.0
# 22                             фэнтези, приключения    33.0
# 23                      зарубежные, триллеры, ужасы     3.0
# 24                                   драмы, русские     1.0
# 25                        драмы, советские, военные     2.0
# 26                   зарубежные, комедии, мелодрамы     3.0
# 27                                  ужасы, триллеры   648.0
# 28                 фантастика, зарубежные, триллеры     2.0
# 29             боевики, ужасы, фантастика, триллеры  2032.0
# 30                                     для взрослых    31.0
# 31                        боевики, русские, военные     1.0
# 32                               мелодрамы, комедии     2.0
# 33                               русские, мелодрамы     1.0
